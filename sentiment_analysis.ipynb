# %% [markdown]
# # Task 4 — Play Store Sentiment Analysis
#
# Uses the Kaggle Play Store User Reviews dataset. Put the downloaded CSV in `../data/`.

# %% [markdown]
# ## Objective
# Classify Play Store reviews into Positive, Neutral and Negative sentiment using TF-IDF, Multinomial Naive Bayes and Logistic Regression.

# %% [markdown]
# ## TF-IDF
# TF-IDF converts reviews into numerical vectors. Term Frequency measures a term's importance within a review, while Inverse Document Frequency reduces the weight of terms appearing across many reviews.

# %%
# %pip -q install -r ../requirements.txt

# %%
# %run ../src/sentiment_analysis.py

# %% [markdown]
# ## Generated outputs
#
# See the `outputs/` directory for sentiment distribution, WordClouds, confusion matrices, model comparison and five misclassified reviews.

# %% [markdown]
# ## Conclusion
#
# Select the model with the highest F1-score from the generated comparison. The project uses actual metrics from the supplied Kaggle dataset and does not hard-code results.
